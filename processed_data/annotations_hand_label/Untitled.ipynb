# %%
import pandas as pd
# for i in range (, 100):
post = str(36)+'.csv'
code = pd.read_csv(post, index_col=0)
for j in range(len(code)):
    print("Post: " + post, end=" ")
    print("Index: " + str(j))
    print()
    print(code.loc[j].text)
    print()
    print(code.loc[j].token)
    print()
    print(code.loc[j]["annotation"])
    input()
# Out:
# Post: 36.csv Index: 0
#
# I've already tried to authenticate using OAuth sucessfully with golang.com/x/oauth2 library.
#
# ['I', "'ve", 'already', 'tried', 'to', 'authenticate', 'using', 'OAuth', 'sucessfully', 'with', 'golang.com/x/oauth2', 'library', '.']
#
# ['PRP', 'VBP', 'RB', 'VBN', 'TO', 'VB', 'VBG', 'NNP', 'RB', 'IN', ‘DIRECTORY', 'NN', '.']
#
# Post: 36.csv Index: 1
#
# // provider variable is oauth2.Config
#
# ['//', 'provider', 'variable', 'is', 'oauth2.Config']
#
# ['COMMENT', 'NN', 'NN', 'VBZ', ‘IDENTIFIER’]
#
# Post: 36.csv Index: 2
#
# // scope is: https://www.googleapis.com/auth/userinfo.email
#
# ['//', 'scope', 'is', ':', 'https:www.googleapis.com/auth/userinfo.email']
#
# ['COMMENT', 'NN', 'VBZ', ':', ‘DIRECTORY']
#
# Post: 36.csv Index: 3
#
# url := provider.AuthCodeURL(``) // redirect URL
#
# ['url', ':=', 'provider.AuthCodeURL(``)', '//', 'redirect', 'URL']
#
# ['IDENTIFIER', 'ASSIGNMENT_OPERATOR', 'FUNCTION_CALL', 'COMMENT', ‘VB', 'NNP']
#
# Post: 36.csv Index: 4
#
#
#
# after getting redirected back from the client, I send the auth_code successfully
#
#
#
# ['after', 'getting', 'redirected', 'back', 'from', 'the', 'client', ',', 'I', 'send', 'the', 'auth_code', 'successfully']
#
# ['IN', 'VBG', 'VBD', 'RB', 'IN', 'DT', 'NN', ',', 'PRP', 'VBP', 'DT', 'NN', 'RB']
#
# Post: 36.csv Index: 5
#
# auth_code := ctx.Request.URL.RawQuery // code=XXXX
#
# ['auth_code', ':=', 'ctx', '.', 'Request', '.', 'URL', '.', 'RawQuery', '//', 'code=XXXX']
#
# ['IDENTIFIER', 'ASSIGNMENT_OPERATOR', 'IDENTIFIER', 'PUNCTUATION', 'IDENTIFIER', 'PUNCTUATION', 'IDENTIFIER', 'PUNCTUATION', 'IDENTIFIER', 'COMMENT', 'NN']
#
# Post: 36.csv Index: 6
#
# if len(auth_code) > 5 {
#
# ['if', 'len(auth_code)', '>', '5', '{']
#
# ['KEYWORD', ‘FUNCTION_CALL’, 'RELATION_OPERATOR', 'DECIMAL_LITERAL', 'PUNCTUATION']
#
# Post: 36.csv Index: 7
#
# auth_code = auth_code[5:] // XXXX
#
# ['auth_code', '=', 'auth_code', '[', '5', ':]', '//', 'XXXX']
#
# ['IDENTIFIER', 'ASSIGNMENT_OPERATOR', 'IDENTIFIER', 'PUNCTUATION', 'DECIMAL_LITERAL', 'PUNCTUATION', 'COMMENT', 'NN']
#
# Post: 36.csv Index: 8
#
# }
#
# ['}']
#
# ['PUNCTUATION']
#
# Post: 36.csv Index: 9
#
# tok, err := provider.Exchange(oauth2.NoContext, auth_code)
#
# ['tok', ',', 'err', ':=', 'provider.Exchange(oauth2.NoContext, auth_code)']
#
# ['IDENTIFIER', 'PUNCTUATION', 'IDENTIFIER', 'ASSIGNMENT_OPERATOR', 'FUNCTION_CALL']
#
# Post: 36.csv Index: 10
#
# if err == nil {
#
# ['if', 'err', '==', 'nil', '{']
#
# ['KEYWORD', 'IDENTIFIER', 'RELATION_OPERATOR', ‘RESERVED', 'PUNCTUATION']
#
# Post: 36.csv Index: 11
#
# client := provider.Client(oauth2.NoContext, tok)
#
# ['client', ':=', 'provider.Client(oauth2.NoContext, tok)']
#
# ['IDENTIFIER', 'ASSIGNMENT_OPERATOR', 'FUNCTION_CALL']
#
# Post: 36.csv Index: 12
#
#     email_url := `https://www.googleapis.com/auth/userinfo.email`
#
# ['email_url', ':=', ‘`https://www.googleapis.com/auth/userinfo.email`’]
#
# ['IDENTIFIER', 'ASSIGNMENT_OPERATOR', 'DIRECTORY']
#
# Post: 36.csv Index: 13
#
#     //Log.Describe(client)
#
# ['//', 'Log.Describe(client)']
#
# ['COMMENT', ‘FUNCTION_CALL’]
#
# Post: 36.csv Index: 14
#
#     response, err := client.Get(email_url)
#
# ['response', ',', 'err', ':=', 'client.Get(email_url)']
#
# ['IDENTIFIER', 'PUNCTUATION', 'IDENTIFIER', 'ASSIGNMENT_OPERATOR', 'FUNCTION_CALL']
#
# Post: 36.csv Index: 15
#
#     if err == nil {
#
# ['if', 'err', '==', 'nil', '{']
#
# ['KEYWORD', 'IDENTIFIER', 'RELATION_OPERATOR', ‘RESERVED', 'PUNCTUATION']
#
# Post: 36.csv Index: 16
#
#         ctx.Render(`login_oauth`, response)
#
# ['ctx.Render(`login_oauth`, response)']
#
# ['FUNCTION_CALL']
#
# Post: 36.csv Index: 17
#
#         //handled = true
#
# ['//', 'handled', '=', 'true']
#
# ['COMMENT', 'IDENTIFIER', ‘ASSIGNMENT_OPERATOR', ‘BOOLEAN_LITERAL’]
#
# Post: 36.csv Index: 18
#
#     }
#
# ['}']
#
# ['PUNCTUATION']
#
# Post: 36.csv Index: 19
#
# }
#
# ['}']
#
# ['PUNCTUATION']
#
# Post: 36.csv Index: 20
#
# //Log.Describe(err)
#
# ['//', 'Log.Describe(err)']
#
# ['COMMENT', ‘FUNCTION_CALL’]
#
# Post: 36.csv Index: 21
#
#
#
# I found nothing that tells the e-mail part on the response (the Body is empty):
#
#
#
# ['I', 'found', 'nothing', 'that', 'tells', 'the', 'e-mail', 'part', 'on', 'the', 'response', '(', 'the', 'Body', 'is', 'empty', ')', ':']
#
# ['PRP', 'VBD', 'NN', 'WDT', 'VBZ', 'DT', 'JJ', 'NN', 'IN', 'DT', 'NN', '(', 'DT', 'NN', 'VBZ', 'JJ', ')', ':']
#
# Post: 36.csv Index: 22
#
# {
#
# ['{']
#
# ['PUNCTUATION']
#
# Post: 36.csv Index: 23
#
# "Status": "200 OK",
#
# ['"Status"', ':', '"200 OK"', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'STRING_LITERAL', 'PUNCTUATION']
#
# Post: 36.csv Index: 24
#
# "StatusCode": 200,
#
# ['"StatusCode"', ':', '200', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'DECIMAL_LITERAL', 'PUNCTUATION']
#
# Post: 36.csv Index: 25
#
# "Proto": "HTTP/1.1",
#
# ['"Proto"', ':', '"HTTP/1.1"', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'STRING_LITERAL', 'PUNCTUATION']
#
# Post: 36.csv Index: 26
#
# "ProtoMajor": 1,
#
# ['"ProtoMajor"', ':', '1', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'DECIMAL_LITERAL', 'PUNCTUATION']
#
# Post: 36.csv Index: 27
#
# "ProtoMinor": 1,
#
# ['"ProtoMinor"', ':', '1', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'DECIMAL_LITERAL', 'PUNCTUATION']
#
# Post: 36.csv Index: 28
#
#     "Header": {
#
# ['"Header"', ':', '{']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'PUNCTUATION']
#
# Post: 36.csv Index: 29
#
#         "Alternate-Protocol": [
#
# ['"Alternate-Protocol"', ':', '[']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'PUNCTUATION']
#
# Post: 36.csv Index: 30
#
# "443:quic,p=0.5"
#
# ['"443:quic,p=0.5"']
#
# ['STRING_LITERAL']
#
# Post: 36.csv Index: 31
#
#         ],
#
# ['],']
#
# ['PUNCTUATION']
#
# Post: 36.csv Index: 32
#
#         "Cache-Control": [
#
# ['"Cache-Control"', ':', '[']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'PUNCTUATION']
#
# Post: 36.csv Index: 33
#
# "private, max-age=0"
#
# ['"private, max-age=0"']
#
# ['STRING_LITERAL']
#
# Post: 36.csv Index: 34
#
#         ],
#
# ['],']
#
# ['PUNCTUATION']
#
# Post: 36.csv Index: 35
#
#         "Content-Type": [
#
# ['"Content-Type"', ':', '[']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'PUNCTUATION']
#
# Post: 36.csv Index: 36
#
#             "text/plain"
#
# ['"text/plain"']
#
# ['STRING_LITERAL']
#
# Post: 36.csv Index: 37
#
#         ],
#
# ['],']
#
# ['PUNCTUATION']
#
# Post: 36.csv Index: 38
#
#         "Date": [
#
# ['"Date"', ':', '[']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'PUNCTUATION']
#
# Post: 36.csv Index: 39
#
# "Tue, 14 Apr 2015 05:52:17 GMT"
#
# ['"Tue, 14 Apr 2015 05:52:17 GMT"']
#
# ['STRING_LITERAL']
#
# Post: 36.csv Index: 40
#
#         ],
#
# ['],']
#
# ['PUNCTUATION']
#
# Post: 36.csv Index: 41
#
#         "Expires": [
#
# ['"Expires"', ':', '[']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'PUNCTUATION']
#
# Post: 36.csv Index: 42
#
# "Tue, 14 Apr 2015 05:52:17 GMT"
#
# ['"Tue, 14 Apr 2015 05:52:17 GMT"']
#
# ['STRING_LITERAL']
#
# Post: 36.csv Index: 43
#
#         ],
#
# ['],']
#
# ['PUNCTUATION']
#
# Post: 36.csv Index: 44
#
#         "Server": [
#
# ['"Server"', ':', '[']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'PUNCTUATION']
#
# Post: 36.csv Index: 45
#
#             "GSE"
#
# ['"GSE"']
#
# ['STRING_LITERAL']
#
# Post: 36.csv Index: 46
#
#         ],
#
# ['],']
#
# ['PUNCTUATION']
#
# Post: 36.csv Index: 47
#
#         "X-Content-Type-Options": [
#
# ['"X-Content-Type-Options"', ':', '[']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'PUNCTUATION']
#
# Post: 36.csv Index: 48
#
#             "nosniff"
#
# ['"nosniff"']
#
# ['STRING_LITERAL']
#
# Post: 36.csv Index: 49
#
#         ],
#
# ['],']
#
# ['PUNCTUATION']
#
# Post: 36.csv Index: 50
#
#         "X-Frame-Options": [
#
# ['"X-Frame-Options"', ':', '[']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'PUNCTUATION']
#
# Post: 36.csv Index: 51
#
#             "SAMEORIGIN"
#
# ['"SAMEORIGIN"']
#
# ['STRING_LITERAL']
#
# Post: 36.csv Index: 52
#
#         ],
#
# ['],']
#
# ['PUNCTUATION']
#
# Post: 36.csv Index: 53
#
#         "X-Xss-Protection": [
#
# ['"X-Xss-Protection"', ':', '[']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'PUNCTUATION']
#
# Post: 36.csv Index: 54
#
# "1; mode=block"
#
# ['"1; mode=block"']
#
# ['STRING_LITERAL']
#
# Post: 36.csv Index: 55
#
#         ]
#
# [']']
#
# ['PUNCTUATION']
#
# Post: 36.csv Index: 56
#
#     },
#
# ['},']
#
# ['PUNCTUATION']
#
# Post: 36.csv Index: 57
#
#     "Body": {}, // empty!!!
#
# ['"Body"', ':', '{},', '//', 'empty', '!', '!', '!']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'PUNCTUATION', 'COMMENT', 'JJ', '.', '.', '.']
#
# Post: 36.csv Index: 58
#
# "ContentLength": -1,
#
# ['"ContentLength"', ':', '-1', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'DECIMAL_LITERAL', 'PUNCTUATION']
#
# Post: 36.csv Index: 59
#
#     "TransferEncoding": [
#
# ['"TransferEncoding"', ':', '[']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'PUNCTUATION']
#
# Post: 36.csv Index: 60
#
#         "chunked"
#
# ['"chunked"']
#
# ['STRING_LITERAL']
# Post: 36.csv Index: 61
#
#     ],
#
# ['],']
#
# ['PUNCTUATION']
#
# Post: 36.csv Index: 62
#
#     "Close": false,
#
# ['"Close"', ':', 'false', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'BOOLEAN_LITERAL', 'PUNCTUATION']
#
# Post: 36.csv Index: 63
#
#     "Trailer": null,
#
# ['"Trailer"', ':', 'null', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', ‘RESERVED', 'PUNCTUATION']
#
# Post: 36.csv Index: 64
#
#     "Request": {
#
# ['"Request"', ':', '{']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'PUNCTUATION']
#
# Post: 36.csv Index: 65
#
#         "Method": "GET",
#
# ['"Method"', ':', '"GET"', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'STRING_LITERAL', 'PUNCTUATION']
#
# Post: 36.csv Index: 66
#
#         "URL": {
#
# ['"URL"', ':', '{']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'PUNCTUATION']
#
# Post: 36.csv Index: 67
#
#             "Scheme": "https",
#
# ['"Scheme"', ':', '"https"', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'STRING_LITERAL', 'PUNCTUATION']
#
# Post: 36.csv Index: 68
#
#             "Opaque": "",
#
# ['"Opaque"', ':', '""', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'STRING_LITERAL', 'PUNCTUATION']
#
# Post: 36.csv Index: 69
#
#             "User": null,
#
# ['"User"', ':', 'null', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', ‘RESERVED', 'PUNCTUATION']
#
# Post: 36.csv Index: 70
#
#             "Host": "www.googleapis.com",
#
# ['"Host"', ':', '"www.googleapis.com"', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'STRING_LITERAL', 'PUNCTUATION']
#
# Post: 36.csv Index: 71
#
#             "Path": "/auth/userinfo.email",
#
# ['"Path"', ':', '"/auth/userinfo.email"', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', ‘DIRECTORY', 'PUNCTUATION']
#
# Post: 36.csv Index: 72
#
#             "RawQuery": "",
#
# ['"RawQuery"', ':', '""', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'STRING_LITERAL', 'PUNCTUATION']
#
# Post: 36.csv Index: 73
#
#             "Fragment": ""
#
# ['"Fragment"', ':', '""']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'STRING_LITERAL']
#
# Post: 36.csv Index: 74
#
#         },
#
# ['},']
#
# ['PUNCTUATION']
#
# Post: 36.csv Index: 75
#
# "Proto": "HTTP/1.1",
#
# ['"Proto"', ':', '"HTTP/1.1"', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'STRING_LITERAL', 'PUNCTUATION']
#
# Post: 36.csv Index: 76
#
# "ProtoMajor": 1,
#
# ['"ProtoMajor"', ':', '1', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'DECIMAL_LITERAL', 'PUNCTUATION']
#
# Post: 36.csv Index: 77
#
# "ProtoMinor": 1,
#
# ['"ProtoMinor"', ':', '1', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'DECIMAL_LITERAL', 'PUNCTUATION']
#
# Post: 36.csv Index: 78
#
#         "Header": {
#
# ['"Header"', ':', '{']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'PUNCTUATION']
#
# Post: 36.csv Index: 79
#
#             "Authorization": [
#
# ['"Authorization"', ':', '[']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'PUNCTUATION']
#
# Post: 36.csv Index: 80
#
# "Bearer ya29.VQFRHDe21t7g2cUhN8sUwjpRRi10XldgLe0RFhMe2ZxgyRo7q90HoKES5WmcucwKqtjZdq_KvYjKiQ"
#
# ['"Bearer ya29.VQFRHDe21t7g2cUhN8sUwjpRRi10XldgLe0RFhMe2ZxgyRo7q90HoKES5WmcucwKqtjZdq_KvYjKiQ"']
#
# ['STRING_LITERAL']
#
# Post: 36.csv Index: 81
#
#             ]
#
# [']']
#
# ['PUNCTUATION']
#
# Post: 36.csv Index: 82
#
#         },
#
# ['},']
#
# ['PUNCTUATION']
#
# Post: 36.csv Index: 83
#
#         "Body": null,
#
# ['"Body"', ':', 'null', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', ‘RESERVED', 'PUNCTUATION']
#
# Post: 36.csv Index: 84
#
# "ContentLength": 0,
#
# ['"ContentLength"', ':', '0', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', ‘DECIMAL_LITERAL', 'PUNCTUATION']
#
# Post: 36.csv Index: 85
#
#         "TransferEncoding": null,
#
# ['"TransferEncoding"', ':', 'null', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', ‘RESERVED', 'PUNCTUATION']
#
# Post: 36.csv Index: 86
#
#         "Close": false,
#
# ['"Close"', ':', 'false', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'BOOLEAN_LITERAL', 'PUNCTUATION']
#
# Post: 36.csv Index: 87
#
#         "Host": "www.googleapis.com",
#
# ['"Host"', ':', '"www.googleapis.com"', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'STRING_LITERAL', 'PUNCTUATION']
#
# Post: 36.csv Index: 88
#
#         "Form": null,
#
# ['"Form"', ':', 'null', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', ‘RESERVED', 'PUNCTUATION']
#
# Post: 36.csv Index: 89
#
#         "PostForm": null,
#
# ['"PostForm"', ':', 'null', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', ‘RESERVED', 'PUNCTUATION']
#
# Post: 36.csv Index: 90
#
#         "MultipartForm": null,
#
# ['"MultipartForm"', ':', 'null', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', ‘RESERVED', 'PUNCTUATION']
#
# Post: 36.csv Index: 91
#
#         "Trailer": null,
#
# ['"Trailer"', ':', 'null', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', ‘RESERVED', 'PUNCTUATION']
#
# Post: 36.csv Index: 92
#
#         "RemoteAddr": "",
#
# ['"RemoteAddr"', ':', '""', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'STRING_LITERAL', 'PUNCTUATION']
#
# Post: 36.csv Index: 93
#
#         "RequestURI": "",
#
# ['"RequestURI"', ':', '""', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'STRING_LITERAL', 'PUNCTUATION']
#
# Post: 36.csv Index: 94
#
#         "TLS": null
#
# ['"TLS"', ':', 'null']
#
# ['STRING_LITERAL', 'PUNCTUATION', ‘RESERVED']
#
# Post: 36.csv Index: 95
#
#     },
#
# ['},']
#
# ['PUNCTUATION']
#
# Post: 36.csv Index: 96
#
#     "TLS": {
#
# ['"TLS"', ':', '{']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'PUNCTUATION']
#
# Post: 36.csv Index: 97
#
#          // really long output
#
# ['//', 'really', 'long', 'output']
#
# ['COMMENT', 'RB', 'JJ', 'NN']
#
# Post: 36.csv Index: 98
#
#     }
#
# ['}']
#
# ['PUNCTUATION']
#
# Post: 36.csv Index: 99
#
# }
#
# ['}']
#
# ['PUNCTUATION']
#
# Post: 36.csv Index: 100
#
# First question, how to get the e-mail correctly? without using Google+ API.
#
# edit #2 I've tried using another scope for oauth2.Config:
#
# ['First', 'question', ',', 'how', 'to', 'get', 'the', 'e-mail', 'correctly', '?', 'without', 'using', 'Google+', 'API', '.', 'edit', '#', '2', 'I', "'ve", 'tried', 'using', 'another', 'scope', 'for', 'oauth2.Config', ':']
#
# ['NNP', 'NN', ',', 'WRB', 'TO', 'VB', 'DT', 'NN', 'RB', '.', 'IN', 'VBG', 'NNP', 'NNP', '.', 'NN', '#', 'CD', 'PRP', 'VBP', 'VBN', 'VBG', 'DT', 'NN', 'IN', 'NN', ':']
#
# Post: 36.csv Index: 101
#
# https://www.googleapis.com/auth/plus.profile.emails.read
#
# ['https://www.googleapis.com/auth/plus.profile.emails.read']
#
# [‘DIRECTORY’]
#
# Post: 36.csv Index: 102
#
# https://www.googleapis.com/auth/plus.login
#
# [‘https://www.googleapis.com/auth/plus.login’]
#
# [‘DIRECTORY’]
#
# Post: 36.csv Index: 103
#
# https://www.googleapis.com/auth/plus.me
#
# [‘https://www.googleapis.com/auth/plus.me’]
#
# [‘DIRECTORY’]
#
# Post: 36.csv Index: 104
#
#
#
# and try to retrieve the e-mail using newer API:
#
#
#
# ['and', 'try', 'to', 'retrieve', 'the', 'e-mail', 'using', 'newer', 'API', ':']
#
# ['CC', 'VB', 'TO', 'VB', 'DT', 'NN', 'VBG', 'JJR', ‘NNP', ':']
#
# Post: 36.csv Index: 105
#
# https://www.googleapis.com/plus/v1/people/me
#
# [‘https://www.googleapis.com/plus/v1/people/me’]
#
# [‘DIRECTORY’]
#
# Post: 36.csv Index: 106
#
# but it gives 403 Forbidden
#
# edit #3 I've tried using another scope:
#
# ['but', 'it', 'gives', '403', 'Forbidden', 'edit', '#', '3', 'I', "'ve", 'tried', 'using', 'another', 'scope', ':']
#
# ['CC', 'PRP', 'VBZ', 'CD', 'NNP', 'NN', '#', 'CD', 'PRP', 'VBP', 'VBN', 'VBG', 'DT', 'NN', ':']
#
# Post: 36.csv Index: 107
#
# openid
#
# ['openid']
#
# ['IDENTIFIER']
#
# Post: 36.csv Index: 108
#
# profile
#
# ['profile']
#
# ['IDENTIFIER']
