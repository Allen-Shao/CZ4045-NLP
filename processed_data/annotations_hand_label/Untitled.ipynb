# %%
import pandas as pd
for i in range (22, 100):
    post = str(i)+'.csv'
    code = pd.read_csv(post, index_col=0)
    for j in range(len(code)):
        print("Post: " + post, end=" ")
        print("Index: " + str(j))
        print()
        print(code.loc[j].text)
        print()
        print(code.loc[j].token)
        print()
        print(code.loc[j]["annotation"])
        input()
# Out:
# Post: 22.csv Index: 0
#
# The following code prettily statisfies your requirement, you can get this code at https://gist.github.com/hygull/645c3dc39c69b6b69c06f5ea9deee41f. The table data has been also provided.
#
# ['The', 'following', 'code', 'prettily', 'statisfies', 'your', 'requirement', ',', 'you', 'can', 'get', 'this', 'code', 'at', 'https://gist.github.com/hygull/645c3dc39c69b6b69c06f5ea9deee41f', '.', 'The', 'table', 'data', 'has', 'been', 'also', 'provided', '.']
#
# ['DT', 'JJ', 'NN', 'RB', 'NNS', 'PRP$', 'NN', ',', 'PRP', 'MD', 'VB', 'DT', 'NN', 'IN', 'DIRECTORY', '.', 'DT', 'NN', 'NN', 'VBZ', 'VBN', 'RB', 'VBN', '.']
#
# Post: 22.csv Index: 1
#
# /**
#
# ['/**']
#
# ['PUNCTUATION']
#
# Post: 22.csv Index: 2
#
#     {
#
# ['{']
#
# ['PUNCTUATION']
#
# Post: 22.csv Index: 3
#
# "created_on": "26 may 2017",
#
# ['"created_on"', ':', '"26 may 2017"', ',']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'STRING_LITERAL', 'PUNCTUATION']
#
# Post: 22.csv Index: 4
#
#         "todos": [
#
# ['"todos"', ':', '[']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'PUNCTUATION']
#
# Post: 22.csv Index: 5
#
#             "go get github.com/go-sql-driver/mysql"
#
# ['"go get github.com/go-sql-driver/mysql"']
#
# ['STRING_LITERAL']
#
# Post: 22.csv Index: 6
#
#         ],
#
# ['],']
#
# ['PUNCTUATION']
#
# Post: 22.csv Index: 7
#
#         "aim": "Reading fname column into []string(slice of strings)"
#
# ['"aim"', ':', '"Reading fname column into []string(slice of strings)"']
#
# ['STRING_LITERAL', 'PUNCTUATION', 'STRING_LITERAL']
#
# Post: 22.csv Index: 8
#
#     }
#
# ['}']
#
# ['PUNCTUATION']
#
# Post: 22.csv Index: 9
#
# */
#
# ['*/']
#
# ['PUNCTUATION']
#
# Post: 22.csv Index: 10
#
# /*
#
# ['/*']
#
# ['PUNCTUATION']
#
# Post: 22.csv Index: 11
#
# mysql> select * from users;
#
# ['mysql', '>', 'select', '*', 'from', 'users', ';']
#
# ['IDENTIFIER', 'RELATION_OPERATOR', 'KEYWORD', 'ARITHMETIC_OPERATOR', 'KEYWORD', 'IDENTIFIER', 'PUNCTUATION']
#
# Post: 22.csv Index: 12
#
# +----+-----------+----------+----------+-------------------------------+--------------+
#
# ['+----+-----------+----------+----------+-------------------------------+--------------+']
#
# ['PUNCTUATION']
#
# Post: 22.csv Index: 13
#
# | id | fname     | lname    | uname    | email                         | contact      |
#
# ['| id | fname     | lname    | uname    | email                         | contact      |']
#
# ['STRING_LITERAL']
#
# Post: 22.csv Index: 14
#
# +----+-----------+----------+----------+-------------------------------+--------------+
#
# ['+----+-----------+----------+----------+-------------------------------+--------------+']
#
# ['PUNCTUATION']
#
# Post: 22.csv Index: 15
#
# |  1 | Rishikesh | Agrawani | hygull   | rishikesh0014051992@gmail.com | 917353787704 |
#
# ['|  1 | Rishikesh | Agrawani | hygull   | rishikesh0014051992@gmail.com | 917353787704 |']
#
# ['STRING_LITERAL']
#
# Post: 22.csv Index: 16
#
# |  2 | Sandeep   | E        | sandeep  | sandeepeswar8@gmail.com       | 919739040038 |
#
# ['|  2 | Sandeep   | E        | sandeep  | sandeepeswar8@gmail.com       | 919739040038 |']
#
# ['STRING_LITERAL']
#
# Post: 22.csv Index: 17
#
# |  3 | Darshan   | Sidar    | darshan  | sidardarshan@gmail.com        | 917996917565 |
#
# [‘|  3 | Darshan   | Sidar    | darshan  | sidardarshan@gmail.com        | 917996917565 |’]
#
# [‘STRING_LITERAL’]
#
# Post: 22.csv Index: 18
#
# |  4 | Surendra  | Prajapat | surendra | surendrakgadwal@gmail.com     | 918385894407 |
#
# [‘|  4 | Surendra  | Prajapat | surendra | surendrakgadwal@gmail.com     | 918385894407 |’]
#
# [‘STRING_LITERAL’]
#
# Post: 22.csv Index: 19
#
# |  5 | Mukesh    | Jakhar   | mukesh   | mjakhar.kjahhar@gmail.com     | 919772254140 |
#
# [‘|  5 | Mukesh    | Jakhar   | mukesh   | mjakhar.kjahhar@gmail.com     | 919772254140 |’]
#
# [‘STRING_LITERAL’]
#
# Post: 22.csv Index: 20
#
# +----+-----------+----------+----------+-------------------------------+--------------+
#
# ['+----+-----------+----------+----------+-------------------------------+--------------+']
#
# ['PUNCTUATION']
#
# Post: 22.csv Index: 21
#
# 5 rows in set (0.00 sec)
#
# ['5', 'rows', 'in', 'set', (, ‘0.00’, 'sec', ')']
#
# ['DECIMAL_LITERAL', 'IDENTIFIER', 'IN', 'IDENTIFIER', 'PUNCTUATION', ‘FLOATING_LITERAL’, ‘NN’, 'PUNCTUATION']
#
# Post: 22.csv Index: 22
#
# mysql>
#
# ['mysql', '>']
#
# ['IDENTIFIER', 'RELATION_OPERATOR']
#
# Post: 22.csv Index: 23
#
# */
#
# ['*/']
#
# ['PUNCTUATION']
#
# Post: 22.csv Index: 24
#
# package main
#
# ['package', 'main']
#
# ['KEYWORD', 'IDENTIFIER']
#
# Post: 22.csv Index: 25
#
# import "fmt"
#
# ['import', '"fmt"']
#
# ['KEYWORD', 'STRING_LITERAL']
#
# Post: 22.csv Index: 26
#
# import "log"
#
# ['import', '"log"']
#
# ['KEYWORD', 'STRING_LITERAL']
#
# Post: 22.csv Index: 27
#
# import (
#
# ['import', '(']
#
# ['KEYWORD', 'PUNCTUATION']
#
# Post: 22.csv Index: 28
#
#     _"github.com/go-sql-driver/mysql"
#
# ['_', '"github.com/go-sql-driver/mysql"']
#
# ['IDENTIFIER', ‘DIRECTORY']
#
# Post: 22.csv Index: 29
#
#     "database/sql"
#
# ['"database/sql"']
#
# [‘DIRECTORY']
#
# Post: 22.csv Index: 30
#
# )
#
# [')']
#
# ['PUNCTUATION']
#
# Post: 22.csv Index: 31
#
# func main() {
#
# ['func', 'main', '()', '{']
#
# ['KEYWORD', 'IDENTIFIER', 'PUNCTUATION', 'PUNCTUATION']
#
# Post: 22.csv Index: 32
#
# // db, err := sql.Open("mysql", ":@tcp(127.0.0.1:)/?charset=utf8" )
#
# ['//', 'db', ',', 'err', ':=', 'sql.Open("mysql", ":@tcp(127.0.0.1:)/?charset=utf8" )']
#
# ['COMMENT', 'IDENTIFIER', 'PUNCTUATION', 'IDENTIFIER', ‘ASSIGNMENT_OPERATOR’, ‘FUNCTION_CALL’]
#
# Post: 22.csv Index: 33
#
# db, err := sql.Open("mysql", "hygull:admin@67@tcp(127.0.0.1:3306)/practice_db?charset=utf8")
#
# ['db', ',', 'err', ':=', 'sql.Open("mysql", "hygull:admin@67@tcp(127.0.0.1:3306)/practice_db?charset=utf8")']
#
# ['IDENTIFIER', 'PUNCTUATION', 'IDENTIFIER', 'ASSIGNMENT_OPERATOR', 'FUNCTION_CALL']
#
# Post: 22.csv Index: 34
#
#     if err != nil {
#
# ['if', 'err', '!=', 'nil', '{']
#
# ['KEYWORD', 'IDENTIFIER', 'RELATION_OPERATOR', ‘RESERVED', 'PUNCTUATION']
#
# Post: 22.csv Index: 35
#
#         log.Fatal(err)
#
# ['log.Fatal(err)']
#
# ['FUNCTION_CALL']
#
# Post: 22.csv Index: 36
#
#     }
#
# ['}']
#
# ['PUNCTUATION']
#
# Post: 22.csv Index: 37
#
#     rows, err := db.Query("select fname from users")
#
# ['rows', ',', 'err', ':=', 'db.Query("select fname from users")']
#
# ['IDENTIFIER', 'PUNCTUATION', 'IDENTIFIER', 'ASSIGNMENT_OPERATOR', 'FUNCTION_CALL']
#
# Post: 22.csv Index: 38
#
#     if err != nil {
#
# ['if', 'err', '!=', 'nil', '{']
#
# ['KEYWORD', 'IDENTIFIER', 'RELATION_OPERATOR', ‘RESERVED', 'PUNCTUATION']
#
# Post: 22.csv Index: 39
#
#         log.Fatal(err)
#
# ['log.Fatal(err)']
#
# ['FUNCTION_CALL']
#
# Post: 22.csv Index: 40
#
#     }
#
# ['}']
#
# ['PUNCTUATION']
#
# Post: 22.csv Index: 41
#
#     firstnames:=[]string{}
#
# ['firstnames', ':=[]', 'string', '{}']
#
# ['IDENTIFIER', 'PUNCTUATION', ‘RESERVED', 'PUNCTUATION']
#
# Post: 22.csv Index: 42
#
#     for rows.Next() {
#
# ['for', 'rows.Next()', '{']
#
# ['KEYWORD', 'FUNCTION_CALL', 'PUNCTUATION']
#
# Post: 22.csv Index: 43
#
#         var fname string
#
# ['var', 'fname', 'string']
#
# ['KEYWORD', 'IDENTIFIER', ‘RESERVED']
#
# Post: 22.csv Index: 44
#
#         rows.Scan(&fname)
#
# ['rows.Scan(&fname)']
#
# ['FUNCTION_CALL']
#
# Post: 22.csv Index: 45
#
#         firstnames = append(firstnames, fname)
#
# ['firstnames', '=', 'append(firstnames, fname)']
#
# ['IDENTIFIER', 'ASSIGNMENT_OPERATOR', ‘FUNCTION_CALL’]
#
# Post: 22.csv Index: 46
#
#     }
#
# ['}']
#
# ['PUNCTUATION']
#
# Post: 22.csv Index: 47
#
#     fmt.Println(firstnames)
#
# ['fmt.Println(firstnames)']
#
# ['FUNCTION_CALL']
#
# Post: 22.csv Index: 48
#
#     db.Close()
#
# ['db.Close()']
#
# ['FUNCTION_CALL']
#
# Post: 22.csv Index: 49
#
# }
#
# ['}']
#
# ['PUNCTUATION']
#
# Post: 22.csv Index: 50
#
# /*
#
# ['/*']
#
# ['PUNCTUATION']
#
# Post: 22.csv Index: 51
#
# [Rishikesh Sandeep Darshan Surendra Mukesh]
#
# [‘[Rishikesh Sandeep Darshan Surendra Mukesh]’]
#
# [‘STRING_LITERAL’]
#
# Post: 22.csv Index: 52
#
# */
#
# ['*/']
#
# ['PUNCTUATION']
#
# Post: 23.csv Index: 0
#
# I want to be able to Marshal/Unmarshall a struct
#
# ['I', 'want', 'to', 'be', 'able', 'to', 'Marshal/Unmarshall', 'a', 'struct']
#
# ['PRP', 'VBP', 'TO', 'VB', 'JJ', 'TO', 'VB', 'DT', 'NN']
#
# Post: 23.csv Index: 1
#
# type MyType struct {
#
# ['type', 'MyType', 'struct', '{']
#
# ['KEYWORD', 'IDENTIFIER', 'KEYWORD', 'PUNCTUATION']
#
# Post: 23.csv Index: 2
#
#     Items       `json:"item"`
#
# ['Items', 'json', ':', '"item"']
#
# ['IDENTIFIER', 'IDENTIFIER', 'PUNCTUATION', 'STRING_LITERAL']
#
# Post: 23.csv Index: 3
#
# }
#
# ['}']
#
# ['PUNCTUATION']
#
# Post: 23.csv Index: 4
#
# Where an example JSON document it must be able to handle is
#
# ['Where', 'an', 'example', 'JSON', 'document', 'it', 'must', 'be', 'able', 'to', 'handle', 'is']
#
# ['WRB', 'DT', 'NN', 'NNP', 'NN', 'PRP', 'MD', 'VB', 'JJ', 'TO', 'VB', 'VBZ']
# Post: 23.csv Index: 5
#
# {"items":["value1", {"x":"y"}, "value3"]}
#
# ['{', '"items"', ':[', '"value1"', ',', '{', '"x"', ':', '"y"', '},', '"value3"', ']}']
#
# ['PUNCTUATION', 'STRING_LITERAL', 'PUNCTUATION', 'STRING_LITERAL', 'PUNCTUATION', 'PUNCTUATION', 'STRING_LITERAL', 'PUNCTUATION', 'STRING_LITERAL', 'PUNCTUATION', 'STRING_LITERAL', 'PUNCTUATION']
#
# Post: 23.csv Index: 6
#
# I am only starting to learn Go.  I am starting to think I might need to impose some restrictions on the structure of the array.  Using the above example, my idea would be
#
# ['I', 'am', 'only', 'starting', 'to', 'learn', 'Go', '.', 'I', 'am', 'starting', 'to', 'think', 'I', 'might', 'need', 'to', 'impose', 'some', 'restrictions', 'on', 'the', 'structure', 'of', 'the', 'array', '.', 'Using', 'the', 'above', 'example', ',', 'my', 'idea', 'would', 'be']
#
# ['PRP', 'VBP', 'RB', 'VBG', 'TO', 'VB', 'NNP', '.', 'PRP', 'VBP', 'VBG', 'TO', 'VB', 'PRP', 'MD', 'VB', 'TO', 'VB', 'DT', 'NNS', 'IN', 'DT', 'NN', 'IN', 'DT', 'NN', '.', 'VBG', 'DT', 'JJ', 'NN', ',', 'PRP$', 'NN', 'MD', 'VB']
#
# Post: 23.csv Index: 7
#
# {"items":[
#
# ['{', '"items"', ':[']
#
# ['PUNCTUATION', 'STRING_LITERAL', 'PUNCTUATION']
#
# Post: 23.csv Index: 8
#
#     {"type":null, "value":"value1"}
#
# ['{', '"type"', ':', 'null', ',', '"value"', ':', '"value1"', '}']
#
# ['PUNCTUATION', 'RESERVED', 'PUNCTUATION', 'IDENTIFIER', 'PUNCTUATION', 'STRING_LITERAL', 'PUNCTUATION', 'STRING_LITERAL', 'PUNCTUATION']
#
# Post: 23.csv Index: 9
#
#     {"type:"x", "value":"y"},
#
# ['{', '"type:"', 'x', '", "', 'value', '":"', 'y', '},']
#
# ['PUNCTUATION', 'STRING_LITERAL', 'IDENTIFIER', 'STRING_LITERAL', 'IDENTIFIER', 'STRING_LITERAL', 'IDENTIFIER', 'PUNCTUATION']
#
# Post: 23.csv Index: 10
#
#     {"type": "value3", "value":"value3"}
#
# ['{', '"type"', ':', '"value3"', ',', '"value"', ':', '"value3"', '}']
#
# ['PUNCTUATION', 'STRING_LITERAL', 'PUNCTUATION', 'STRING_LITERAL', 'PUNCTUATION', 'STRING_LITERAL', 'PUNCTUATION', 'STRING_LITERAL', 'PUNCTUATION']
#
# Post: 23.csv Index: 11
#
# ]}
#
# [']}']
#
# ['PUNCTUATION']
#
# Post: 23.csv Index: 12
#
# Then modelling the objects inside with their own struct.  I'd rather do it the first way, is it possible?
#
# ['Then', 'modelling', 'the', 'objects', 'inside', 'with', 'their', 'own', 'struct', '.', 'I', "'d", 'rather', 'do', 'it', 'the', 'first', 'way', ',', 'is', 'it', 'possible', '?']
#
# ['RB', 'VBG', 'DT', 'NNS', 'IN', 'IN', 'PRP$', 'JJ', 'NN', '.', 'PRP', 'MD', 'RB', 'VB', 'PRP', 'DT', 'JJ', 'NN', ',', 'VBZ', 'PRP', 'JJ', '.']
#
# Post: 24.csv Index: 0
#
# You should not try to get value from sC channel in main function because the only value you send to it is  consumed by getC function in seperate go routine. While trying to read sC channel main function blocks waiting for something and it never ends. Go routine getS is finished, go routine getC has consumed value from channel sC and has also finished. There is nothing in channel sC anymore.
#
# The possible solution is to create another channel s2C and send to it value received from sC channel.
#
# The complete correct code would look like this:
#
# ['You', 'should', 'not', 'try', 'to', 'get', 'value', 'from', 'sC', 'channel', 'in', 'main', 'function', 'because', 'the', 'only', 'value', 'you', 'send', 'to', 'it', 'is', 'consumed', 'by', 'getC', 'function', 'in', 'seperate', 'go', 'routine', '.', 'While', 'trying', 'to', 'read', 'sC', 'channel', 'main', 'function', 'blocks', 'waiting', 'for', 'something', 'and', 'it', 'never', 'ends', '.', 'Go', 'routine', 'getS', 'is', 'finished', ',', 'go', 'routine', 'getC', 'has', 'consumed', 'value', 'from', 'channel', 'sC', 'and', 'has', 'also', 'finished', '.', 'There', 'is', 'nothing', 'in', 'channel', 'sC', 'anymore', '.', 'The', 'possible', 'solution', 'is', 'to', 'create', 'another', 'channel', 's2C', 'and', 'send', 'to', 'it', 'value', 'received', 'from', 'sC', 'channel', '.', 'The', 'complete', 'correct', 'code', 'would', 'look', 'like', 'this', ':']
#
# ['PRP', 'MD', 'RB', 'VB', 'TO', 'VB', 'NN', 'IN', 'NN', 'NN', 'IN', 'NNP', 'NN', 'IN', 'DT', 'JJ', 'NN', 'PRP', 'VBP', 'TO', 'PRP', 'VBZ', 'VBN', 'IN', 'NNP', 'NN', 'IN', 'JJ', 'VBP', ‘NN’, '.', 'IN', 'VBG', 'TO', 'VB', 'NN', 'NNS', 'NNP', 'NN', 'VPZ', 'VBG', 'IN', 'NN', 'CC', 'PRP', 'RB', 'VBZ', '.', 'NNP', 'NN', 'NNP', 'VBZ', 'VBN', ',', 'NNP', ‘NN', 'NNP', 'VBZ', 'VBN', 'NN', 'IN', 'NN', 'NNP', 'CC', 'VBZ', 'RB', 'VBN', '.', 'EX', 'VBZ', 'NN', 'IN', 'NN', 'NNP', 'RB', '.', 'DT', 'JJ', 'NN', 'VBZ', 'TO', 'VB', 'DT', 'NN', 'NNP', 'CC', 'NN', 'TO', 'PRP', 'NN', 'VBD', 'IN', 'NNP', 'NN', '.', 'DT', 'JJ', ‘JJ', 'NN', 'MD', 'VB', 'IN', 'DT', ':']
#
# Post: 24.csv Index: 1
#
# package main
#
# ['package', 'main']
#
# ['KEYWORD', 'IDENTIFIER']
#
# Post: 24.csv Index: 2
#
# func main() {
#
# ['func', 'main', '()', '{']
#
# ['KEYWORD', 'IDENTIFIER', 'PUNCTUATION', 'PUNCTUATION']
#
# Post: 24.csv Index: 3
#
#     sC := make(chan string)
#
# ['sC', ':=', ‘make(chan string)’]
#
# ['IDENTIFIER', 'ASSIGNMENT_OPERATOR', ‘FUNCTION_CALL’]
#
# Post: 24.csv Index: 4
#
#     go getS(sC)
#
# ['go', 'getS(sC)']
#
# ['KEYWORD', ‘FUNCTION_CALL’]
#
# Post: 24.csv Index: 5
#
# s2C := make(chan string)
#
# ['s2C', ':=', ‘make(chan string)']
#
# ['IDENTIFIER', 'ASSIGNMENT_OPERATOR', ‘FUNCTION_CALL’]
#
# Post: 24.csv Index: 6
#
#     cC := make(chan string)
#
# ['cC', ':=', ‘make(chan string)']
#
# ['IDENTIFIER', 'ASSIGNMENT_OPERATOR', ‘FUNCTION_CALL’]
